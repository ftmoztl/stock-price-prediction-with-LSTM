# %%
# to reach wandb via google colab
#!pip install wandb -qqq
#!apt install tree
# Out:
#      |████████████████████████████████| 1.9 MB 16.7 MB/s
#      |████████████████████████████████| 173 kB 73.7 MB/s
#      |████████████████████████████████| 182 kB 70.9 MB/s
#      |████████████████████████████████| 62 kB 1.5 MB/s
#      |████████████████████████████████| 168 kB 62.2 MB/s
#      |████████████████████████████████| 168 kB 72.2 MB/s
#      |████████████████████████████████| 166 kB 13.0 MB/s
#      |████████████████████████████████| 166 kB 66.4 MB/s
#      |████████████████████████████████| 162 kB 18.4 MB/s
#      |████████████████████████████████| 162 kB 47.4 MB/s
#      |████████████████████████████████| 158 kB 60.8 MB/s
#      |████████████████████████████████| 157 kB 54.2 MB/s
#      |████████████████████████████████| 157 kB 62.2 MB/s
#      |████████████████████████████████| 157 kB 64.4 MB/s
#      |████████████████████████████████| 157 kB 62.7 MB/s
#      |████████████████████████████████| 157 kB 63.7 MB/s
#      |████████████████████████████████| 157 kB 63.5 MB/s
#      |████████████████████████████████| 157 kB 64.4 MB/s
#      |████████████████████████████████| 156 kB 60.4 MB/s
#   Building wheel for pathtools (setup.py) ... done
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'apt autoremove' to remove it.
# The following NEW packages will be installed:
#   tree
# 0 upgraded, 1 newly installed, 0 to remove and 20 not upgraded.
# Need to get 40.7 kB of archives.
# After this operation, 105 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 tree amd64 1.7.0-5 [40.7 kB]
# Fetched 40.7 kB in 0s (134 kB/s)
# Selecting previously unselected package tree.
# (Reading database ... 124016 files and directories currently installed.)
# Preparing to unpack .../tree_1.7.0-5_amd64.deb ...
# Unpacking tree (1.7.0-5) ...
# Setting up tree (1.7.0-5) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...

# %%
import wandb
wandb.login()
# Out:
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
# ··········
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# True

# %%
import random
import torch
import torchvision
from torch.utils.data import TensorDataset
from tqdm.auto import tqdm
import pandas as pd
import numpy as np
from torch.autograd import Variable
from sklearn.preprocessing import MinMaxScaler
import torch
import torch.nn as nn
from sklearn.preprocessing import StandardScaler
from math import sqrt
import math, time
from sklearn.metrics import mean_squared_error,mean_absolute_percentage_error
from torch.utils.data import DataLoader

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## RAW DATA VERSIONING

# %% [markdown]
# The raw dataset of Samsung stock prices was uploaded to the W&B platform to keep and versioning.

# %%
# Ensure deterministic behavior
torch.backends.cudnn.deterministic = True
random.seed(0)
torch.manual_seed(0)
torch.cuda.manual_seed_all(0)

# Device configuration
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

def load():
    """
    # Load the data
    """

    path="/content/drive/***" # data comes from Google Drive, you can enter your path
    data=pd.read_csv(path+"Data_Samsung.csv")
    data=data.copy()
    return data
dataset=load()

# upload dataset as an adtifact to the Weight & Bias platform

with wandb.init(project="DSS",job_type="load-data", name="rawdata-load-SAMSUNG"):
  artifact = wandb.Artifact( 'Samsung','Data')
  table = wandb.Table(columns=list(dataset.columns), data=dataset.to_numpy())
  artifact.add(table, "rawdata")
  wandb.log_artifact(artifact)
# Out:
# Tracking run with wandb version 0.13.5
# Run data is saved locally in <code>/content/wandb/run-20221116_140024-2s7ow5vl</code>
# Syncing run <strong><a href="https://wandb.ai/metu_datacraft/DSS/runs/2s7ow5vl" target="_blank">rawdata-load-SAMSUNG</a></strong> to <a href="https://wandb.ai/metu_datacraft/DSS" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.119 MB of 0.119 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# Synced <strong style="color:#cdcd00">rawdata-load-SAMSUNG</strong>: <a href="https://wandb.ai/metu_datacraft/DSS/runs/2s7ow5vl" target="_blank">https://wandb.ai/metu_datacraft/DSS/runs/2s7ow5vl</a><br/>Synced 4 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20221116_140024-2s7ow5vl/logs</code>

# %% [markdown]
# ## MISSING DATA HANDLING

# %% [markdown]
# In this section, missing values were filled by using 10 days moving average values.

# %%
def preprocess(data):
    """
    ## Prepare the data
    """
    data["Price"]=data["Price"].str.replace(",","")
    data["Open"]=data["Open"].str.replace(",","")
    data["High"]=data["High"].str.replace(",","")
    data["Low"]=data["Low"].str.replace(",","")
    data["Change %"]=data["Change %"].str.replace("%","")
    data["Change %"]=data["Change %"].str.replace(",","")
    data["Change %"]=pd.to_numeric(data["Change %"])
    data['Vol.']=data['Vol.'].apply(lambda x: str(x))
    data['Volume']=data['Vol.'].apply(lambda x: float(x.replace("M",""))*100000 if "M" in x  else float(x.replace("K",""))*1000  if "K" in x  else x)
    data["Open"]=pd.to_numeric(data["Open"],downcast="float",errors="coerce")
    data["High"]=pd.to_numeric(data["High"],downcast="float",errors="coerce")
    data["Price"]=pd.to_numeric(data["Price"],downcast="float",errors="coerce")
    data["Volume"]=pd.to_numeric(data["Volume"],downcast="float",errors="coerce")
    data["Low"]=pd.to_numeric(data["Low"],downcast="float",errors="coerce")
    return data

# %%
#create an empty dataset which includes all days in the time period 
def create_date_table(start='2017-01-03', end='2022-10-31'):
   df = pd.DataFrame({"Date": pd.date_range(start, end)})
   return df

# %%
#fill the empty data with 10 days moving average
def fill_missing(data):
  data = data[["Date","Price","Open","High","Low","Change %","Volume"]]
  data = data[data['Price']<1000000]
  data.loc[(data['Change %']<-20), "Change %"] = np.nan
  data['Date'] = pd.to_datetime(data.Date)
  data_date = create_date_table()
  df = data_date.merge(data, left_on='Date', right_on='Date', how='left')
  df=df[["Date","Price","Open","High","Low","Change %","Volume"]]
  for column in df.columns:
    if df[column].dtypes!='<M8[ns]':
      df[column+'_MA']=df[column].rolling(10, min_periods=1).mean()
      df[column].fillna(df[column+'_MA'], inplace=True)
  df['Date']=df['Date'].astype(str) 
  filled_df = df[["Date","Price","Open","High","Low","Change %","Volume"]]
  return filled_df

# %%
#log the new version of the dataset to W&B
#the new version the dataset includes the missing data
def preprocess_and_log():

    with wandb.init(project="DSS") as r:
         
        # ✔️ declare which artifact we'll be using
        artifact = r.use_artifact('metu_datacraft/DSS/Samsung:v0', type='Data')
        table = artifact.get('rawdata')
        dataset= {"Date": table.get_column("Date"),"Price":table.get_column("Price"),"Open":table.get_column("Open"),
                  "High":table.get_column("High"), "Low":table.get_column("Low") , "Vol.": table.get_column("Vol."),
                  "Change %":table.get_column("Change %")}

        data = pd.DataFrame(dataset)
        preprocessed_data=preprocess(data)
        filled_data=fill_missing(preprocessed_data)
        
        with wandb.init(project="DSS",job_type="preprocess-data", name="filleddata-load-SAMSUNG"):
          artifact = wandb.Artifact( 'Samsung','Data')
          table = wandb.Table(columns=list(filled_data.columns), data=filled_data.to_numpy())
          artifact.add(table, "filled_data")
          wandb.log_artifact(artifact)
preprocess_and_log()
# Out:
# Tracking run with wandb version 0.13.5
# Run data is saved locally in <code>/content/wandb/run-20221116_140145-3lxikiim</code>
# Syncing run <strong><a href="https://wandb.ai/metu_datacraft/DSS/runs/3lxikiim" target="_blank">fast-bee-95</a></strong> to <a href="https://wandb.ai/metu_datacraft/DSS" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# wandb:   1 of 1 files downloaded.
# Finishing last run (ID:3lxikiim) before initializing another...
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# Synced <strong style="color:#cdcd00">fast-bee-95</strong>: <a href="https://wandb.ai/metu_datacraft/DSS/runs/3lxikiim" target="_blank">https://wandb.ai/metu_datacraft/DSS/runs/3lxikiim</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20221116_140145-3lxikiim/logs</code>
# Successfully finished last run (ID:3lxikiim). Initializing new run:<br/>
# Tracking run with wandb version 0.13.5
# Run data is saved locally in <code>/content/wandb/run-20221116_140148-1ogcrjxu</code>
# Syncing run <strong><a href="https://wandb.ai/metu_datacraft/DSS/runs/1ogcrjxu" target="_blank">filleddata-load-SAMSUNG</a></strong> to <a href="https://wandb.ai/metu_datacraft/DSS" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.152 MB of 0.152 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# Synced <strong style="color:#cdcd00">filleddata-load-SAMSUNG</strong>: <a href="https://wandb.ai/metu_datacraft/DSS/runs/1ogcrjxu" target="_blank">https://wandb.ai/metu_datacraft/DSS/runs/1ogcrjxu</a><br/>Synced 4 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20221116_140148-1ogcrjxu/logs</code>

# %% [markdown]
# ## DATA VERSION 3 (Removing weekends)

# %% [markdown]
# In this section, the filled days of weekends were removed from the dataset. And it was versioned to the W&B platform as a 3rd version of the dataset.

# %%
with wandb.init(project="DSS") as r:
         
        # ✔️ declare which artifact we'll be using
        artifact = r.use_artifact('metu_datacraft/DSS/Samsung:v1', type='Data')
        table = artifact.get('filled_data')
        dataset= {"Date": table.get_column("Date"),"Price":table.get_column("Price"),"Open":table.get_column("Open"),
                  "High":table.get_column("High"), "Low":table.get_column("Low") , "Volume": table.get_column("Volume"),
                  "Change":table.get_column("Change %")}
        data = pd.DataFrame(dataset)

        #remove weekends from dataset
        data['Date']=pd.to_datetime(data['Date'])
        data=data[(data['Date'].dt.day_name()!='Saturday') & (data['Date'].dt.day_name()!='Sunday')]
        data['Date']=data['Date'].astype(str)  

        #add to WB
        with wandb.init(project="DSS",job_type="preprocess-data",name="weekdata-load-SAMSUNG"):
           artifact = wandb.Artifact( 'Samsung','Data')
           table = wandb.Table(columns=list(data.columns), data=data.to_numpy())
           artifact.add(table, "weekday_data")
           wandb.log_artifact(artifact)
# Out:
# wandb: Currently logged in as: becemerce (metu_datacraft). Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.13.6
# Run data is saved locally in <code>/content/wandb/run-20221207_141631-1m6y8ucg</code>
# Syncing run <strong><a href="https://wandb.ai/metu_datacraft/DSS/runs/1m6y8ucg" target="_blank">kind-moon-694</a></strong> to <a href="https://wandb.ai/metu_datacraft/DSS" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# wandb:   1 of 1 files downloaded.
# Finishing last run (ID:1m6y8ucg) before initializing another...
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# Synced <strong style="color:#cdcd00">kind-moon-694</strong>: <a href="https://wandb.ai/metu_datacraft/DSS/runs/1m6y8ucg" target="_blank">https://wandb.ai/metu_datacraft/DSS/runs/1m6y8ucg</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20221207_141631-1m6y8ucg/logs</code>
# Successfully finished last run (ID:1m6y8ucg). Initializing new run:<br/>
# Tracking run with wandb version 0.13.6
# Run data is saved locally in <code>/content/wandb/run-20221207_141635-2j1h6ch2</code>
# Syncing run <strong><a href="https://wandb.ai/metu_datacraft/DSS/runs/2j1h6ch2" target="_blank">weekdata-load-SAMSUNG</a></strong> to <a href="https://wandb.ai/metu_datacraft/DSS" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.102 MB of 0.102 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# Synced <strong style="color:#cdcd00">weekdata-load-SAMSUNG</strong>: <a href="https://wandb.ai/metu_datacraft/DSS/runs/2j1h6ch2" target="_blank">https://wandb.ai/metu_datacraft/DSS/runs/2j1h6ch2</a><br/>Synced 4 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20221207_141635-2j1h6ch2/logs</code>
